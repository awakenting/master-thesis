# %%
import time
import matplotlib

#matplotlib.use('TKAgg')

import SwarmStartleLooming as sw
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(200)
# Initialize Parameters
N = 10
L = 50
total_time = 50.0
dt = 0.001

speed0 = 1.5
alpha = 1
noisep = 0.01
noisev = 0.0
BC = 0 #'along_wall'
IC = 10 # initial condition

repstrength = 1.0
algstrength = 0.5
attstrength = 0.3

reprange = 1.0
algrange = 5.0
attrange = 25.0

repsteep = -20

output = 0.05

int_type = 'voronoi'
startle = True

amplitude_startle = 50.0
duration_startle = 0.070

# initialize system parameters
paraSystem = sw.BaseParams(N=N, L=L, time=total_time, dt=dt, BC=BC, IC=IC, output=output, int_type=int_type, startle=startle)
# initialize prey parameters
paraFish = sw.AgentParams(paraSystem, speed0=speed0, alpha=alpha,
                          repstrength=repstrength, reprange=reprange, repsteepness=repsteep,
                          algstrength=algstrength, algrange=algrange,
                          attstrength=attstrength, attrange=attrange,
                          noisep=noisep, noisev=noisev,
                          amplitude_startle=amplitude_startle,
                          duration_startle=duration_startle,
                          print_startles=True,
                          r_m=10*1e6,
                          tau_m=0.023,
                          e_l=-0.079,
                          v_t=-0.061,
                          vt_std=0.000,
                          tau_rho=0.001,
                          rho_null=3.6,
                          rho_null_std=0.7,
                          rho_scale=8.16 * 1e6,
                          exc_scale=30,
                          noise_std_exc=0.0027,
                          noise_std_inh=0.000,
                          vis_input_m=3,
                          vis_input_b=0,
                          vis_input_method='max',
                          vis_input_k=3
                          )

# %%
starttime = time.time()

outData, agentData = sw.SingleRun(paraSystem, paraFish)

endtime = time.time()
print('Total time needed: ' + str(int((endtime - starttime))) + ' seconds or '
      + str(int((endtime - starttime) / 60)) + ' min '
      + 'or ' + str(int((endtime - starttime) / 3600)) + ' hours')
# Out:
# Individual 0 startles!!!!
# Individual 4 startles!!!!
# Individual 9 startles!!!!
# Individual 6 startles!!!!
# Individual 0 startles!!!!
# Individual 8 startles!!!!
# Individual 6 startles!!!!
# Individual 0 startles!!!!
# Individual 8 startles!!!!
# Individual 6 startles!!!!
# Individual 8 startles!!!!
# Individual 0 startles!!!!
# Individual 4 startles!!!!
# Individual 9 startles!!!!
# Individual 0 startles!!!!
# Individual 0 startles!!!!
# Individual 6 startles!!!!
# Individual 3 startles!!!!
# Individual 0 startles!!!!
# Individual 3 startles!!!!
# Individual 0 startles!!!!
# Individual 3 startles!!!!
# Individual 3 startles!!!!
# Individual 1 startles!!!!
# Individual 1 startles!!!!
# Individual 7 startles!!!!
# Individual 6 startles!!!!
# Individual 7 startles!!!!
# Individual 1 startles!!!!
# Done!
# Total time needed: 94 seconds or 1 min or 0 hours

# %%
np.random.seed(200)
# Initialize Parameters
N = 40
L = 50
total_time = 50.0
dt = 0.001

speed0 = 1.5
alpha = 1
noisep = 0.01
noisev = 0.0
BC = 0 #'along_wall'
IC = 10 # initial condition

repstrength = 1.0
algstrength = 0.5
attstrength = 0.3

reprange = 1.0
algrange = 5.0
attrange = 25.0

repsteep = -20

output = 0.05

int_type = 'voronoi_matrix'
startle = True

amplitude_startle = 50.0
duration_startle = 0.070

# initialize system parameters
paraSystem = sw.BaseParams(N=N, L=L, time=total_time, dt=dt, BC=BC, IC=IC, output=output, int_type=int_type, startle=startle)
# initialize prey parameters
paraFish = sw.AgentParams(paraSystem, speed0=speed0, alpha=alpha,
                          repstrength=repstrength, reprange=reprange, repsteepness=repsteep,
                          algstrength=algstrength, algrange=algrange,
                          attstrength=attstrength, attrange=attrange,
                          noisep=noisep, noisev=noisev,
                          amplitude_startle=amplitude_startle,
                          duration_startle=duration_startle,
                          print_startles=True,
                          r_m=10*1e6,
                          tau_m=0.023,
                          e_l=-0.079,
                          v_t=-0.061,
                          vt_std=0.000,
                          tau_rho=0.001,
                          rho_null=3.6,
                          rho_null_std=0.7,
                          rho_scale=8.16 * 1e6,
                          exc_scale=30,
                          noise_std_exc=0.0027,
                          noise_std_inh=0.000,
                          vis_input_m=3,
                          vis_input_b=0,
                          vis_input_method='max',
                          vis_input_k=3
                          )

# %%
starttime = time.time()

outData, agentData = sw.SingleRun(paraSystem, paraFish)

endtime = time.time()
print('Total time needed: ' + str(int((endtime - starttime))) + ' seconds or '
      + str(int((endtime - starttime) / 60)) + ' min '
      + 'or ' + str(int((endtime - starttime) / 3600)) + ' hours')
# Out:
# /home/warkentin/Dropbox/Master/thesis/code/SwarmStartleLooming.py:529: RuntimeWarning: invalid value encountered in true_divide
#   dUX = np.divide(dX, distmatrix)
# /home/warkentin/Dropbox/Master/thesis/code/SwarmStartleLooming.py:530: RuntimeWarning: invalid value encountered in true_divide
#   dUY = np.divide(dY, distmatrix)
# Individual 3 startles!!!!
# Individual 5 startles!!!!
# Individual 25 startles!!!!
# Individual 35 startles!!!!
# Individual 0 startles!!!!
# Individual 4 startles!!!!
# Individual 6 startles!!!!
# Individual 7 startles!!!!
# Individual 9 startles!!!!
# Individual 11 startles!!!!
# Individual 13 startles!!!!
# Individual 16 startles!!!!
# Individual 18 startles!!!!
# Individual 19 startles!!!!
# Individual 21 startles!!!!
# Individual 22 startles!!!!
# Individual 23 startles!!!!
# Individual 33 startles!!!!
# Individual 34 startles!!!!
# Individual 38 startles!!!!
# Individual 39 startles!!!!
# Individual 37 startles!!!!
# Individual 31 startles!!!!
# Individual 5 startles!!!!
# Individual 4 startles!!!!
# Individual 9 startles!!!!
# Individual 11 startles!!!!
# Individual 13 startles!!!!
# Individual 16 startles!!!!
# Individual 19 startles!!!!
# Individual 22 startles!!!!
# Individual 27 startles!!!!
# Individual 32 startles!!!!
# Individual 33 startles!!!!
# Individual 35 startles!!!!
# Individual 38 startles!!!!
# Individual 6 startles!!!!
# Individual 37 startles!!!!
# Individual 25 startles!!!!
# Individual 30 startles!!!!
# Individual 7 startles!!!!
# Individual 15 startles!!!!
# Individual 5 startles!!!!
# Individual 3 startles!!!!
# Individual 4 startles!!!!
# Individual 9 startles!!!!
